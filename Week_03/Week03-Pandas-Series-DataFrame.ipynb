# %% [markdown]
# # Load packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas Series

# %% [markdown]
# ## Construction

# %% [markdown]
# ## Selection

# %% [markdown]
# ## Operations
#
# - Addition
# - Multiplication
# - Square

# %% [markdown]
# ### indexing and additions

# %% [markdown]
# # DataFrame
#
# - Construcat a data frame from series above

# %% [markdown]
# ## Pivoting etc

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada',  'Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002, 2003, 2000, 2001, 2002, 2001, 2002, 2003],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2, 1.5, 1.7, 3.6, 2.4, 2.9, 3.2],
'city': ['a', 'a', 'a', 'b', 'b', 'b', 'c', 'c', 'c', 'd', 'd', 'd']}

# %%
df_1 = pd.DataFrame(data)
