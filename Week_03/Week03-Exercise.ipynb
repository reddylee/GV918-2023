# %% [markdown]
# # Week 03 Class

# %% [markdown]
# # Numpy

# %% [markdown]
# ## Exercise 1: Creating and Manipulating 1D Arrays
#
# Create a NumPy array named `arr1` with the elements `[1, 3, 5, 7, 9]`.

# %% [markdown]
# Create another array named `arr2` with the elements `[2, 4, 6, 8, 10]`.

# %% [markdown]
# Add `arr1` and `arr2` element-wise and store the result in a new array called `result_array`.

# %% [markdown]
# Calculate the square of each element in `result_array`.

# %% [markdown]
# ## Exercise 2: Creating and Manipulating 2D Arrays
#
# Create a 2D NumPy array named matrix with the following
#
#
# ```
# [[1, 2, 3],
#  [4, 5, 6],
#  [7, 8, 9]]
# ```

# %% [markdown]
# Exercise 3: Slicing with `iloc` and `loc`
#
# Create a DataFrame using NumPy with the following data:

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
        'Age': [25, 30, 35, 40, 45],
        'Salary': [50000, 60000, 75000, 90000, 80000]}

# %% [markdown]
# Set the 'Name' column as the index of the DataFrame.

# %% [markdown]
# Use iloc to select and print the data of the first two rows and the first two columns.

# %% [markdown]
# Use loc to select and print the data of the person with the name 'Charlie' (including all columns).

# %% [markdown]
# # Pandas

# %% [markdown]
# Open the following csv file, and following questions

# %%
# !wget -O 1918-2019election_results.csv https://www.dropbox.com/scl/fi/4skl95dqrcyaor9wfuve3/1918-2019election_results.csv?rlkey=4n4rlld2oqm3i9kjfn9fcqlz2&dl=1

# %% [markdown]
# ### How many general elections in there?

# %% [markdown]
# ### Looking at the latest election
#
# Answer the following:
#
# 1. How many rows in the data?
# 2. Which electoral constituency had the highest turnouts?
# 3. Get the same information as 2. for each region.
# 4. How many electoral districts are there where the Consertavives win?
# 5. What's the vote percentage of the Conservatives in each election and region?

# %% [markdown]
# # Pandas and Numpy

# %% [markdown]
# 1. Generating Random Series and Creating DataFrame
# Generate three NumPy random series, each of size 100. Name them `series_1`, `series_2`, and `series_3`.
#
# 2. Create a new series named `linear_combination` as the linear combination of the three series:
# `linear_combination=2×series_1+0.5×series_2−series_3+noise`,
# where noise is a random noise series generated using numpy.random.
#
# 3. Combine all the generated series into a DataFrame named data_frame. Use the series as columns in the DataFrame.
#
# 4. Display the first 5 rows of the DataFrame.
