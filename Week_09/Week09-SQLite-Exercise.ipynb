# %% [markdown]
# ## Description
#
# In this exersise, you will use the UK Parliment petition data stored in a SQLite database. The database contains the information on the number of signatuures for a number of most popular petitions as of 30 Nov, 2023.

# %% [markdown]
# ## Download the dbfile

# %%
# !wget "https://www.dropbox.com/scl/fi/3tv2vrnc1wxqm85gkubor/petition.sqlite?rlkey=drfhmgur1n3w7c891c3ujdeqp&dl=1" -O petition.sqlite
# Out:
# --2023-11-30 17:14:16--  https://www.dropbox.com/scl/fi/3tv2vrnc1wxqm85gkubor/petition.sqlite?rlkey=drfhmgur1n3w7c891c3ujdeqp&dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.64.18
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.64.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb3d244445ade47dc8c3eb98973.dl.dropboxusercontent.com/cd/0/inline/CIjOEr3N4CNZm5k-AqOGPo2jCmxwELTTdIZqnIvU_ZOQPYO7xvpFLycN9EWx4X3HDmuyzw2qKUBIfVa-ggN8kPWNslGvEQP6YWyoaSDIuy-CJO-opzOL5KAVflr30arSKJE/file?dl=1# [following]
# --2023-11-30 17:14:17--  https://ucb3d244445ade47dc8c3eb98973.dl.dropboxusercontent.com/cd/0/inline/CIjOEr3N4CNZm5k-AqOGPo2jCmxwELTTdIZqnIvU_ZOQPYO7xvpFLycN9EWx4X3HDmuyzw2qKUBIfVa-ggN8kPWNslGvEQP6YWyoaSDIuy-CJO-opzOL5KAVflr30arSKJE/file?dl=1
# Resolving ucb3d244445ade47dc8c3eb98973.dl.dropboxusercontent.com (ucb3d244445ade47dc8c3eb98973.dl.dropboxusercontent.com)... 162.125.64.15
# Connecting to ucb3d244445ade47dc8c3eb98973.dl.dropboxusercontent.com (ucb3d244445ade47dc8c3eb98973.dl.dropboxusercontent.com)|162.125.64.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 962560 (940K) [application/binary]
# Saving to: ‘petition.sqlite’
#
# petition.sqlite     100%[===================>] 940.00K  --.-KB/s    in 0.07s
#
# 2023-11-30 17:14:17 (13.5 MB/s) - ‘petition.sqlite’ saved [962560/962560]

# %% [markdown]
# ## Connect to the database

# %% [markdown]
# ## Check the database contents
#
# Look up the `sqlite_master` table and figure out how many tables exist in this database. Also, get the understanding of the each table by browsing it.

# %% [markdown]
# ## Answer the following questions using SQL queries and pandas dataFrames generated from SQL queries.
#
# 1. How many different petitions in this database?
# 2. What is the petition with the largest number of signatures? What the petition is about?
# 3. For the petition above (2.), which electoral constituency had the largest number of signatures? What's the number of signatures?
# 4. Who is the MP of the constituency (3.)?
# 5. Find out how many peitions are about election by searching the `action` column in one of tables.
# 6. Find whether there are correlations between the parties representing electoral constituencies and the number of signatures for the petition(s) you find (5.)
