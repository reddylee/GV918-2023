# %%
import pandas as pd
from urllib.request import urlopen
import json
from time import sleep

# %% [markdown]
# # Parliament members
#
# The following is the names and ids of MPs. Using ids, we will extract more information through parliament members API.

# %%
# !wget https://www.dropbox.com/s/n038gl81vpanv4e/df_all_mps_sub.csv

# %%
df_mps = pd.read_csv("df_all_mps_sub.csv")
df_mps.head()
# Out:
#      id              name
# 0   172  Abbott, Ms Diane
# 1  4212  Abrahams, Debbie
# 2  4057      Adams, Nigel
# 3  4639      Afolami, Bim
# 4  1586     Afriyie, Adam

# %% [markdown]
# ## Get members

# %% [markdown]
# The API we are going to access is this:
#
# * Documentation: https://members-api.parliament.uk/index.html
#
# * Endpoint: https://members-api.parliament.uk/api/Members/{id}

# %% [markdown]
# ### Kier Stermer
#
# Now let's try to access Kier Stermer's information. The following line will provide his id:

# %%
df_mps[df_mps['name'].str.contains("Starmer")]
# Out:
#        id           name gender   party                   const
# 563  4514  Starmer, Keir      M  Labour  Holborn and St Pancras

# %% [markdown]
# #### Create URL
#
# We need to construct an url to access. The following code is an example of that using `.format()` method. For this example, it's not necessary as simple concaetnation is sufficient, but for more complicated cases, this will help.

# %%
url_template = 'https://members-api.parliament.uk/api/Members/{id}'
url_template.format(id = "4514")
# Out:
# 'https://members-api.parliament.uk/api/Members/4514'

# %% [markdown]
# Now, let's access the page with `urlopen()` and hand the response to `json.load()`

# %%
res = urlopen(url_template.format(id = current_id))
member_json = json.load(res)

# %% [markdown]
# Once you load json, you can print out it with `json.dumps()`

# %%
print(json.dumps(member_json, indent=4))

# %% [markdown]
# Let's extract
# - gender
# - party
# - electoral constituency
# - membership start date
#
# For example first elected canbe ectracted like this:

# %%
member_json.get("value").get('latestHouseMembership').get('membershipStartDate')
# Out:
# '2015-05-07T00:00:00'

# %% [markdown]
# Let's extract all 4 fields, convert them (with id) to a dataframe, called `df_info`
#
# The results looks like this:
#
# |id |membershipStartDate|gender             |party|membershipFrom|
# |---|-------------------|-------------------|-----|--------------|
# |4514|2015-05-07T00:00:00|M                  |Labour|Holborn and St Pancras|

# %% [markdown]
# #### Accessing contact information
#
# There is another Members API, which is about the contact information.
#
# * Endpoint: https://members-api.parliament.uk/api/Members/{id}/Contact
#
# Let's accces it, and extract some more information

# %%
url_template_contact = 'https://members-api.parliament.uk/api/Members/{id}/Contact'
url_template_contact.format(id = "4514")
# Out:
# 'https://members-api.parliament.uk/api/Members/4514/Contact'

# %% [markdown]
# Access the endpoint and extract some information

# %% [markdown]
# Dump the json

# %% [markdown]
# Get website address and twitter as an dictionary. The resulting outcome is like this:
#
# ```
# {'Website': 'http://www.keirstarmer.com/',
#  'Twitter': 'https://twitter.com/keir_starmer'}
# ```

# %% [markdown]
# Convert the dictionary into a dataframe

# %% [markdown]
# Concatenate with `df_info`

# %% [markdown]
# The resulting dataframe should look like this:
#
# |id  |membershipStartDate|gender|party |membershipFrom        |Website                    |Twitter                         |
# |----|-------------------|------|------|----------------------|---------------------------|--------------------------------|
# |4514|2015-05-07T00:00:00|M     |Labour|Holborn and St Pancras|http://www.keirstarmer.com/|https://twitter.com/keir_starmer|

# %% [markdown]
# ## Combine the previous work as a function

# %%
def get_member_info(id, sleep_sec = 3):
  df_member_info = pd.DataFrame()
  sleep(sleep_sec)
  return(df_member_info)

# %% [markdown]
# Check if the function works

# %%
get_member_info('4212')

# %% [markdown]
# #### loop over first 20 members and cocatenate. Check if all works

# %%
list_df = [get_member_info(cid) for cid in df_mps[:20]['id']]
df_20_members = pd.concat(list_df, axis = 0)
df_20_members
# Out:
#      id  membershipStartDate gender           party  \
# 0   172  1987-06-11T00:00:00      F          Labour
# 0  4212  2011-01-13T00:00:00      F          Labour
# 0  4057  2010-05-06T00:00:00      M    Conservative
# 0  4639  2017-06-08T00:00:00      M    Conservative
# 0  1586  2005-05-05T00:00:00      M    Conservative
# 0  4741  2019-12-12T00:00:00      F    Conservative
# 0  4069  2010-05-06T00:00:00      M    Conservative
# 0  4138  2010-05-06T00:00:00      F          Labour
# 0  4747  2019-12-12T00:00:00      M          Labour
# 0  4411  2015-05-07T00:00:00      F    Conservative
# 0  4573  2016-06-16T00:00:00      F          Labour
# 0  4667  2017-06-08T00:00:00      M          Labour
# 0  4788  2019-12-12T00:00:00      F          Labour
# 0  4743  2019-12-12T00:00:00      M    Conservative
# 0  4742  2019-12-12T00:00:00      M    Conservative
# 0  4032  2010-05-06T00:00:00      M    Conservative
# 0  4512  2019-12-12T00:00:00      F    Conservative
# 0  4623  2017-06-08T00:00:00      F          Labour
# 0  4362  2015-05-07T00:00:00      M    Conservative
# 0  4244  2011-05-05T00:00:00      M  Labour (Co-op)
#
#                       membershipFrom                            Website  \
# 0  Hackney North and Stoke Newington      http://www.dianeabbott.org.uk
# 0        Oldham East and Saddleworth  http://www.debbieabrahams.org.uk/
# 0                   Selby and Ainsty     http://www.selbyandainsty.com/
# 0              Hitchin and Harpenden                                NaN
# 0                            Windsor        http://www.adamafriyie.org/
# 0   Cities of London and Westminster    https://www.nickieaiken.org.uk/
# 0                            Waveney        http://www.peteraldous.com/
# 0              Bethnal Green and Bow       http://www.rushanaraali.org/
# 0             Birmingham, Hall Green                                NaN
# 0                            Telford          http://www.lucyallan.com/
# 0                            Tooting         http://www.drrosena.co.uk/
# 0                        Weaver Vale                                NaN
# 0                             Putney                                NaN
# 0                           Ashfield                                NaN
# 0           Wolverhampton South West                                NaN
# 0                             Pudsey   https://www.stuartandrew.org.uk/
# 0                         Eastbourne                                NaN
# 0                              Gower  http://www.toniaantoniazzi.co.uk/
# 0                          Charnwood                                NaN
# 0                    Leicester South        http://www.jonashworth.org/
#
#                                Twitter  \
# 0    https://twitter.com/HackneyAbbott
# 0  https://twitter.com/Debbie_abrahams
# 0                                  NaN
# 0       https://twitter.com/BimAfolami
# 0      https://twitter.com/AdamAfriyie
# 0  https://twitter.com/twocitiesnickie
# 0     https://twitter.com/peter_aldous
# 0     https://twitter.com/rushanaraali
# 0                                  NaN
# 0        https://twitter.com/lucyallan
# 0         https://twitter.com/DrRosena
# 0   https://twitter.com/MikeAmesburymp
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0     https://twitter.com/stuartandrew
# 0  https://twitter.com/caroline_ansell
# 0  https://twitter.com/ToniaAntoniazzi
# 0                                  NaN
# 0      https://twitter.com/JonAshworth
#
#                                    Facebook  \
# 0                                       NaN
# 0                                       NaN
# 0    https://www.facebook.com/nigel.adamsmp
# 0                                       NaN
# 0                                       NaN
# 0  https://www.facebook.com/twocitiesnickie
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0         https://www.facebook.com/DrRosena
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0                                       NaN
# 0    https://www.facebook.com/ToniaForGower
# 0                                       NaN
# 0                                       NaN
#
#                                     Instagram
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0  https://www.instagram.com/twocitiesnickie/
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
